# %%
import pandas as pd

# %% [markdown]
# The data used in this notebook are generously provided by https://www.kaggle.com/datasets/berkeleyearth/climate-change-earth-surface-temperature-data

# %%
climate = pd.read_csv("../public/GlobalLandTemperaturesByMajorCity.csv")
climate = climate.dropna()

# %%
climate.City.unique()
# Out:
# array(['Chicago', 'Los Angeles', 'New York'], dtype=object)

# %%
climate = climate[climate.Country == "United States"]
climate_2000 = climate[climate['dt'].str.startswith("2")]
# climate["year"] = climate.dt.apply(lambda x: x[:4])
# climate["month"] = climate.dt.apply(lambda x: x[5:7])
climate_2000.iloc[:10]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 54748  2000-01-01               0.137                          0.595  Chicago
# 54749  2000-02-01               4.083                          0.615  Chicago
# 54750  2000-03-01               8.274                          0.193  Chicago
# 54751  2000-04-01               7.615                          0.676  Chicago
# 54752  2000-05-01              13.867                          0.589  Chicago
# 54753  2000-06-01              17.939                          0.690  Chicago
# 54754  2000-07-01              21.087                          0.397  Chicago
# 54755  2000-08-01              22.840                          0.392  Chicago
# 54756  2000-09-01              19.061                          0.261  Chicago
# 54757  2000-10-01              15.110                          0.164  Chicago
#
#              Country Latitude Longitude  year month
# 54748  United States   42.59N    87.27W  2000    01
# ...

# %%
climate_2000.to_json("../public/climate.json", orient="records")
