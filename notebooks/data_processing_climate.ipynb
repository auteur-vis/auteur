# %%
import pandas as pd

# %% [markdown]
# The data used in this notebook are generously provided by https://www.kaggle.com/datasets/dhruvildave/google-trends-dataset

# %%
climate = pd.read_csv("../public/GlobalLandTemperaturesByMajorCity.csv")
climate
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...

# %%
climate = climate[climate.Country == "United States"]
climate.iloc[:10]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 51674  1743-11-01               5.436                          2.205  Chicago
# 51675  1743-12-01                 NaN                            NaN  Chicago
# 51676  1744-01-01                 NaN                            NaN  Chicago
# 51677  1744-02-01                 NaN                            NaN  Chicago
# 51678  1744-03-01                 NaN                            NaN  Chicago
# 51679  1744-04-01               8.766                          2.357  Chicago
# 51680  1744-05-01              11.605                          2.102  Chicago
# 51681  1744-06-01              17.965                          1.989  Chicago
# 51682  1744-07-01              21.680                          1.786  Chicago
# 51683  1744-08-01                 NaN                            NaN  Chicago
#
#              Country Latitude Longitude
# 51674  United States   42.59N    87.27W
# ...

# %%
google_men_women = pd.concat([google_men, google_women])

# %%
google_men_women.iloc[:10]
# Out:
#    location  year category  rank            query
# 5    Global  2001      Men     1      Nostradamus
# 6    Global  2001      Men     2  Osama bin Laden
# 7    Global  2001      Men     3           Eminem
# 8    Global  2001      Men     4  Michael Jackson
# 9    Global  2001      Men     5     Howard Stern
# 75   Global  2002      Men     1           Eminem
# 76   Global  2002      Men     2        Brad Pitt
# 77   Global  2002      Men     3    David Beckham
# 78   Global  2002      Men     4    Josh Hartnett
# 79   Global  2002      Men     5             2Pac

# %%
coffee_filtered.to_json("../public/arabica_data_cleaned_top15.json", orient="records")
